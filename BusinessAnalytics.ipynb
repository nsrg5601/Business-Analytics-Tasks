# %% [markdown]
# <a href="https://colab.research.google.com/github/nsrg5601/Business-Analytics-Tasks/blob/main/BusinessAnalytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as py
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8feab24c-4464-4688-b1f2-b3cd6381267b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8feab24c-4464-4688-b1f2-b3cd6381267b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BreadBasket_DMS.csv to BreadBasket_DMS (1).csv

# %%
df=pd.read_csv("BreadBasket_DMS.csv")
df
# Out:
#              Date      Time  Transaction           Item
# 0      2016-10-30  09:58:11            1          Bread
# 1      2016-10-30  10:05:34            2   Scandinavian
# 2      2016-10-30  10:05:34            2   Scandinavian
# 3      2016-10-30  10:07:57            3  Hot chocolate
# 4      2016-10-30  10:07:57            3            Jam
# ...           ...       ...          ...            ...
# 21288  2017-04-09  14:32:58         9682         Coffee
# 21289  2017-04-09  14:32:58         9682            Tea
# 21290  2017-04-09  14:57:06         9683         Coffee
# 21291  2017-04-09  14:57:06         9683         Pastry
# 21292  2017-04-09  15:04:24         9684      Smoothies
#
# [21293 rows x 4 columns]

# %%
df.head()
# Out:
#          Date      Time  Transaction           Item
# 0  2016-10-30  09:58:11            1          Bread
# 1  2016-10-30  10:05:34            2   Scandinavian
# 2  2016-10-30  10:05:34            2   Scandinavian
# 3  2016-10-30  10:07:57            3  Hot chocolate
# 4  2016-10-30  10:07:57            3            Jam

# %%
df.shape
# Out:
# (21293, 4)

# %%
df.info
# Out:
# <bound method DataFrame.info of              Date      Time  Transaction           Item
# 0      2016-10-30  09:58:11            1          Bread
# 1      2016-10-30  10:05:34            2   Scandinavian
# 2      2016-10-30  10:05:34            2   Scandinavian
# 3      2016-10-30  10:07:57            3  Hot chocolate
# 4      2016-10-30  10:07:57            3            Jam
# ...           ...       ...          ...            ...
# 21288  2017-04-09  14:32:58         9682         Coffee
# 21289  2017-04-09  14:32:58         9682            Tea
# 21290  2017-04-09  14:57:06         9683         Coffee
# 21291  2017-04-09  14:57:06         9683         Pastry
# 21292  2017-04-09  15:04:24         9684      Smoothies
#
# [21293 rows x 4 columns]>

# %%
df = df.dropna()

# %%
df
# Out:
#              Date      Time  Transaction           Item
# 0      2016-10-30  09:58:11            1          Bread
# 1      2016-10-30  10:05:34            2   Scandinavian
# 2      2016-10-30  10:05:34            2   Scandinavian
# 3      2016-10-30  10:07:57            3  Hot chocolate
# 4      2016-10-30  10:07:57            3            Jam
# ...           ...       ...          ...            ...
# 21288  2017-04-09  14:32:58         9682         Coffee
# 21289  2017-04-09  14:32:58         9682            Tea
# 21290  2017-04-09  14:57:06         9683         Coffee
# 21291  2017-04-09  14:57:06         9683         Pastry
# 21292  2017-04-09  15:04:24         9684      Smoothies
#
# [21293 rows x 4 columns]

# %%
df = df[df.Item != "NONE"]

# %%
df.shape
# Out:
# (20507, 4)

# %%
df.value_counts("Item")
# Out:
# Item
# Coffee            5471
# Bread             3325
# Tea               1435
# Cake              1025
# Pastry             856
#                   ...
# Chicken sand         1
# Gift voucher         1
# Olum & polenta       1
# Raw bars             1
# Adjustment           1
# Length: 94, dtype: int64

# %%
dups = df.pivot_table(index = ['Transaction'], aggfunc ='size')
dups
# Out:
# Transaction
# 1       1
# 2       2
# 3       3
# 4       1
# 5       3
#        ..
# 9680    1
# 9681    4
# 9682    4
# 9683    2
# 9684    1
# Length: 9465, dtype: int64

# %%
dups.max()
# Out:
# 11

# %%
dups1 = df.pivot_table(index = ['Item'], aggfunc ='size')
dups1
# Out:
# Item
# Adjustment                    1
# Afternoon with the baker     44
# Alfajores                   369
# Argentina Night               7
# Art Tray                     38
#                            ...
# Tshirt                       21
# Valentine's card             13
# Vegan Feast                  16
# Vegan mincepie               54
# Victorian Sponge              7
# Length: 94, dtype: int64

# %%
dups1.max()
# Out:
# 5471

# %%
dups2 = df.pivot_table(index = ['Date','Transaction','Item'], aggfunc ='size')
dups2
# Out:
# Date        Transaction  Item
# 2016-10-30  1            Bread            1
#             2            Scandinavian     2
#             3            Cookies          1
#                          Hot chocolate    1
#                          Jam              1
#                                          ..
# 2017-04-09  9682         Tacos/Fajita     1
#                          Tea              1
#             9683         Coffee           1
#                          Pastry           1
#             9684         Smoothies        1
# Length: 18887, dtype: int64

# %%
dups2.max()
# Out:
# 4

# %%
dups2.nlargest(60)
# Out:
# Date        Transaction  Item
# 2017-02-14  6560         Coffee           4
# 2017-02-19  6850         Coffee           4
#             6887         Coffee           4
# 2016-10-31  104          Coffee           3
# 2016-11-01  247          Coffee           3
# 2016-11-03  346          Coffee           3
# 2016-11-05  635          Coffee           3
# 2016-11-26  2156         Coffee           3
# 2016-11-27  2196         Coffee           3
# 2016-12-03  2552         Sandwich         3
# 2016-12-04  2613         Hot chocolate    3
#             2614         Coffee           3
#             2625         Coffee           3
# 2016-12-05  2682         Coffee           3
# 2016-12-12  3058         Bread            3
# 2016-12-13  3070         Fudge            3
# 2016-12-16  3309         Coffee           3
# 2016-12-17  3340         Coffee           3
#             3344         Coffee           3
# 2016-12-19  3449         Fudge            3
# 2016-12-21  3580         Coffee           3
# ...

# %% [markdown]
# 1)from the above data of Items count , The items which were sold in the maximum numbers are "Coffee" and "Bread" i.e, considering the maximum amount of transactions happening everyday per particular item,coffee and bread are sold maximum no of.time combinedly and individually.So combination of bread and coffee increase the sales on regualr basis.

# %%
dups3 = df.pivot_table(index = ['Time'], aggfunc ='size')
dups3.nlargest(10)
# Out:
# Time
# 12:07:39    16
# 10:45:21    13
# 10:55:19    13
# 14:38:01    13
# 13:43:08    12
# 12:07:19    11
# 12:45:14    11
# 12:58:48    11
# 13:14:04    11
# 13:44:56    11
# dtype: int64

# %% [markdown]
# 2)At the afternoon time of the day the sales are more influential.More number of sales are happening between the the time frame of almost 11 am to 1:30 pm(considering the time lapse of 10 to 15 mins lag or gain).

# %%
dups1.nsmallest(60)
# Out:
# Item
# Adjustment                        1
# Bacon                             1
# Chicken sand                      1
# Gift voucher                      1
# Olum & polenta                    1
# Polenta                           1
# Raw bars                          1
# The BART                          1
# Bowl Nic Pitt                     2
# Chimichurri Oil                   2
# Fairy Doors                       2
# Hack the stack                    2
# Siblings                          2
# Spread                            2
# Brioche and salami                3
# Caramel bites                     3
# Cherry me Dried fruit             3
# Raspberry shortbread sandwich     3
# Bread Pudding                     4
# Bare Popcorn                      5
# Mortimer                          5
# Panatone                          5
# Basket                            6
# Crepes                            6
# Half slice Monster                6
# Honey                             6
# ...

# %% [markdown]
# 3)From the above observation,we can notice that the servings which is happened to be sold once(or) less than twenty times should be replaced because there are no more sales of the particular item other than that day,which may lead to the reserves of excess stocks interms of items and ingredients.

# %%
fd1= df[df["Item"]=='Pastry']
fd1
# Out:
#              Date      Time  Transaction    Item
# 8      2016-10-30  10:13:03            5  Pastry
# 11     2016-10-30  10:16:55            6  Pastry
# 14     2016-10-30  10:19:12            7  Pastry
# 17     2016-10-30  10:20:51            8  Pastry
# 30     2016-10-30  10:30:14           12  Pastry
# ...           ...       ...          ...     ...
